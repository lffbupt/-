# %% [markdown]
# # 残差分析

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as st

# %% [markdown]
# ## 0.建模前的数据考察
# * 需要考察每个单变量的分布状况，对其有一个总的认识
# * 数据是否偏斜、是否有异常值（有：异常值的原因，是否需要删除该异常值）
# * 对多维图进行两两组对的二维图
# ### 0.1 直方图

# %%
np.random.seed(19680801)

fig, ax = plt.subplots()
x = 30*np.random.randn(10000)
mu = x.mean()
median = np.median(x)
sigma = x.std()
textstr = '\n'.join((
    r'$\mu=%.2f$' % (mu, ),
    r'$\mathrm{median}=%.2f$' % (median, ),
    r'$\sigma=%.2f$' % (sigma, )))

ax.hist(x, 50)
# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

# place a text box in upper left in axes coords
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

plt.show()

# %% [markdown]
# ### 0.2 箱线图

# %%
spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low))
d2 = np.concatenate((spread, center, flier_high, flier_low))
# Making a 2-D array only works if all the columns are the
# same length.  If they are not, then use a list instead.
# This is actually more efficient because boxplot converts
# a 2-D array into a list of vectors internally anyway.
data = [data, d2, d2[::2]]
# Multiple box plots on one Axes
fig, ax = plt.subplots()
ax.boxplot(data)

plt.show()

# %% [markdown]
# ### 0.3 二维图

# %%
data = pd.read_csv("/Users/luofeifei/study/DataAnalysis/All_Data/P103.txt",sep="\t")

# %%
import seaborn as sns

# %%
sns.pairplot(data,kind="scatter")
plt.show()

# %%
sns.heatmap(data.corr(),linewidths=0.2, cmap="YlGnBu",annot=True)

# %% [markdown]
# ### 0.4 三维图

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(16, 12))  #参数为图片大小
ax = fig.gca(projection='3d') 
ax.scatter(data["X1"],data["X2"],data["Y"])
ax.set_xlabel('X1 Label')
ax.set_ylabel('X2 Label')
ax.set_zlabel('Y Label')
ax.view_init(70, 24)

# %% [markdown]
# ## 1.强影响点
# * 要么是X异常，要么是Y异常，Y异常通过考察标准化残差图一般就能看得出来

# %%
river_data = pd.read_csv("/Users/luofeifei/study/DataAnalysis/All_Data/P010.txt",sep="\t")
river_data.set_index("River",inplace=True,drop=True)

# %%
def get_pii(river_data):
    X_C = sm.add_constant(river_data)
    XX_T = np.dot(X_C.values.T,X_C.values)
    left = np.dot(X_C,(np.linalg.inv(XX_T)))
    P = np.dot(left,X_C.T)
    pii = []
    for i in range(P.shape[0]):
        pii.append(P[i][i])
    return pii

# %%
pii = get_pii(river_data["ComIndl"])

# %%
river_model = smf.ols("Nitrogen~ComIndl",river_data).fit()

# %%
print(river_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Nitrogen   R-squared:                       0.284
# Model:                            OLS   Adj. R-squared:                  0.244
# Method:                 Least Squares   F-statistic:                     7.124
# Date:                Wed, 09 Sep 2020   Prob (F-statistic):             0.0156
# Time:                        10:08:06   Log-Likelihood:                -7.9589
# No. Observations:                  20   AIC:                             19.92
# Df Residuals:                      18   BIC:                             21.91
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.9988      0.104      9.636      0.000       0.781       1.217
# ComIndl        0.3078      0.115      2.669      0.016       0.066       0.550
# ==============================================================================
# Omnibus:                        1.513   Durbin-Watson:                   1.611
# Prob(Omnibus):                  0.469   Jarque-Bera (JB):                1.265
# Skew:                           0.562   Prob(JB):                        0.531
# Kurtosis:                       2.493   Cond. No.                         1.94
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sigma_hat = np.sqrt(sum(river_model.resid.values**2)/river_model.df_resid)

# %%
standard_error = river_model.resid.values/(sigma_hat*np.sqrt(1-np.array(pii)))

# %%
plt.plot(pii,'ko')

# %%
fig, ax = plt.subplots()
plt.plot(standard_error,'ko')
#ax.set_xticklabels(river_data.index.values)
plt.show()

# %% [markdown]
# ### 回归线与散点图

# %%
fig, ax = plt.subplots()
plt.plot(river_data.ComIndl.values,river_data.Nitrogen.values,"ko")
parameter = np.polyfit(river_data.ComIndl.values,river_data.Nitrogen.values, 1)
f = np.poly1d(parameter)
plt.plot(river_data.ComIndl.values,f(river_data.ComIndl.values),"b--")
ax.set_xlabel("ComIndl")
ax.set_ylabel("Nitrogen")
plt.show()

# %% [markdown]
# ### Cook距离

# %%
#Cook距离
Ci = (standard_error**2/2)*np.array(pii)/(1-np.array(pii))

# %%
fig, ax = plt.subplots()
plt.plot(Ci,'ko')
plt.show()

# %% [markdown]
# ### Hadi度量

# %%
#Hadi度量
di = river_model.resid.values/np.sqrt(sum(river_model.resid.values**2))
Hi = np.array(pii)/(1-np.array(pii)) + 2/(1-np.array(pii))*(di**2)/(1-di**2)

# %%
np.set_printoptions(suppress=True)
np.set_printoptions(precision=2)
Hi
# Out:
# array([0.06, 0.07, 0.58, 0.77, 2.04, 0.1 , 0.6 , 0.37, 0.07, 0.08, 0.13,
#        0.14, 0.15, 0.13, 0.16, 0.09, 0.12, 0.09, 0.19, 0.11])

# %%
fig, ax = plt.subplots()
plt.plot(Hi,'ko')
plt.show()

# %% [markdown]
# ### L-R，位势-残差图

# %%
#L-R
L = np.array(pii)/(1-np.array(pii))
R = 2/(1-np.array(pii))*(di**2)/(1-di**2)

# %%
fig, ax = plt.subplots()
plt.plot(R,L,'ko')
plt.show()

# %% [markdown]
# # 2.变量作用

# %%
Climb_data = pd.read_csv("/Users/luofeifei/study/DataAnalysis/All_Data/P120.txt",sep="  \t",engine='python')
Climb_data.set_index("Hill Race",inplace=True,drop=True)

# %%
Climb_model = smf.ols("Time~Distance+Climb",data=Climb_data).fit()
print(Climb_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Time   R-squared:                       0.919
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                     181.7
# Date:                Wed, 09 Sep 2020   Prob (F-statistic):           3.40e-18
# Time:                        12:02:01   Log-Likelihood:                -285.41
# No. Observations:                  35   AIC:                             576.8
# Df Residuals:                      32   BIC:                             581.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -539.4829    258.161     -2.090      0.045   -1065.339     -13.627
# Distance     373.0727     36.068     10.343      0.000     299.604     446.542
# Climb          0.6629      0.123      5.387      0.000       0.412       0.914
# ==============================================================================
# Omnibus:                       47.910   Durbin-Watson:                   2.249
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              233.983
# Skew:                           3.026   Prob(JB):                     1.55e-51
# Kurtosis:                      14.127   Cond. No.                     4.20e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.2e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### 残差加分量图

# %%
re_X = Climb_model.resid.values + Climb_model.params.Distance*Climb_data.Distance.values

# %%
fig, ax = plt.subplots()
plt.plot(Climb_data.Distance.values,re_X,'ko')
plt.show()
